# %% [markdown]
# # 필요한 라이브러리 import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Box plot

# %%
sns.boxplot(y='total_bill', data=tips)
plt.grid()
plt.show()

# %%
sns.boxplot(x='total_bill', data=tips)
plt.grid()
plt.show()

# %% [markdown]
# * 성별 tip의 box plot

# %%
sns.boxplot(x='sex',y='tip', data=tips)
plt.show()

# %%
tips[tips.sex =='Male'].tip.describe()
# Out:
# count    157.000000
# mean       3.089618
# std        1.489102
# min        1.000000
# 25%        2.000000
# 50%        3.000000
# 75%        3.760000
# max       10.000000
# Name: tip, dtype: float64

# %%
tips[tips.sex =='Female'].tip.describe()
# Out:
# count    87.000000
# mean      2.833448
# std       1.159495
# min       1.000000
# 25%       2.000000
# 50%       2.750000
# 75%       3.500000
# max       6.500000
# Name: tip, dtype: float64

# %% [markdown]
# 요일별 tip의 box plot

# %%
sns.boxplot(x='day', y='tip', data=tips)
plt.show()

# %% [markdown]
# subplot을 생성해서 각각 그래프 그리기

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

sns.boxplot(y='total_bill', data=tips, ax=ax[0])
sns.boxplot(y='tip', data=tips, ax=ax[1])

plt.subplots_adjust(wspace=0.9)
plt.show()

# %% [markdown]
# 2개의 subplot에 흡연여부별 tip, 시간별 tip의 box plot

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(8,4))

sns.boxplot(x='smoker', y='tip', data=tips, ax=ax[0])
sns.boxplot(x='time', y='tip', data=tips, ax=ax[1])

plt.show()

# %% [markdown]
# total_bill 히스토그램을 세로 막대로 표현

# %%
sns.histplot(x=tips.total_bill)
plt.show()

# %% [markdown]
# total_bill 히스토그램을 가로 막대로 표현

# %%
sns.histplot(y=tips.total_bill)
plt.show()

# %% [markdown]
# * subplot 2개를 상/하로 생성
# * 위쪽 subplot에는 tip의 box plot을 가로 방향으로 그림
# * 아래쪽 subplot에는 tip의 히스토그램을 그림.

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(8,4))

sns.boxplot(x='tip', data=tips, ax=ax[0])
sns.histplot(x='tip', data=tips, ax=ax[1], bins=10)

plt.show()

# %% [markdown]
# # Bar plot

# %% [markdown]
# ## `countplot()`
# 카테고리 타입 변수(컬럼)의 빈도수(count, frequency)를 막대로 표현한 그래프

# %%
# 성별 빈도수
sns.countplot(x='sex',data=tips)
plt.show()

# %%
# 흡연자/ 비흡연자 수 가로 막대 그래프
sns.countplot(y='smoker', data=tips)
plt.show()

# %%
# 요일별 성별 빈도수
sns.countplot(x='day', hue='sex', data=tips)
# hue 파라미터 : 카테고리 별로 색깔을 다르게 시각화할 때
plt.show()

# %%
tips[tips['day']=='Thur']['sex'].value_counts()
# tips[tips.day=='Thur'].sex.value_counts()
# Out:
# Female    32
# Male      30
# Name: sex, dtype: int64

# %%
# 성별 흡연/비흡연자 수 가로 막대 그래프

sns.countplot(x='sex', hue='smoker', data=tips)
plt.show()

# %%
sns.countplot(y='sex', hue='smoker', data=tips)
plt.show()

# %%
tips[tips['sex']=='Male']['smoker'].value_counts()
# Out:
# No     97
# Yes    60
# Name: smoker, dtype: int64

# %% [markdown]
# ## `barplot()`
#
# * 그룹별 변수(컬럼)의 기술 통계량(평균,중앙값, 최대값, 최솟값,...)을 막대로 시각화.

# %%
# 남성 tip의 평균
tips[tips['sex']=='Male']['tip'].mean()
# Out:
# 3.0896178343949052

# %%
# 여성 tip의 평균
tips[tips.sex=='Female'].tip.mean()
# Out:
# 2.833448275862069

# %%
sns.barplot(x='sex', y='tip', data=tips)
# estimator 파라미터 : 연속형 변수의 통계량을 계산할 함수를 지정. 기본값은 mean함수
plt.show()

# %%
# 성별 tip의 최댓값
sns.barplot(x='sex', y='tip', data=tips, estimator=np.max, ci=None)
# ci 파라미터 : confidence interval(신뢰구간) None = 오차막대보이지않는다. 기본값은 sd
plt.show()

# %%
# 요일별 tip의 평균 가로 막대 그래프
sns.barplot(y='day',x='tip', data=tips, estimator=np.mean)
plt.show()

# %%
# 요일별 성별 tip의 평균 세로 막대 그래프
sns.barplot(y='tip', x='day', hue='sex', data=tips)
plt.show()

# %%
sns.barplot(x='sex', y='tip', hue='day', data=tips)
plt.show()

# %% [markdown]
# #산점도(Scatter plot)

# %% [markdown]
# ##`scatterplot()`

# %%
# tip ~ total_bill
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.grid()
plt.show()

# %% [markdown]
# ## `regplot()`
#
# regression plot: 산점도 + 선형회귀직선

# %%
sns.regplot(x='total_bill', y='tip', data=tips)
plt.grid()
plt.show()

# %% [markdown]
# ##`jointplot()`
#
# joing plot: 산점도 + 히스토그램

# %%
sns.jointplot(x='total_bill', y='tip', data=tips)

plt.show()

# %% [markdown]
# * tip ~ total_bill 산점도. marker의 색깔을 성별에 따라 다르게 시각화.

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', data=tips)
plt.show()

# %% [markdown]
# * tip ~ total_bill 산점도. marker의 색깔은 성별에 따라서,
# marker의 크기는 인원수에 따라서 다르게 시각화.

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', 
                size='size', data=tips)
plt.show()

# %% [markdown]
# * tip ~ total_bill 산점도. marker의 색깔은 성별에 따라서,
# marker의 모양은 흡연여부에 따라서 다르게 시각화.

# %%
sns.scatterplot(x='total_bill', y='tip', hue='sex', 
                style='smoker', data=tips)
plt.show()

# %% [markdown]
# # Line plot(선 그래프)

# %%
np.random.seed(1) #난수 발생순서가 정해짐
df= pd.DataFrame({'x1': np.arange(1,11),
                  'x2': np.random.rand(10)})
df
# Out:
#    x1        x2
# 0   1  0.417022
# 1   2  0.720324
# 2   3  0.000114
# 3   4  0.302333
# 4   5  0.146756
# 5   6  0.092339
# 6   7  0.186260
# 7   8  0.345561
# 8   9  0.396767
# 9  10  0.538817

# %%
sns.lineplot(x='x1', y='x2', data=df, marker='o', 
             linestyle='--', color='#00ff00')
plt.grid()
plt.show()

# %% [markdown]
# # Category plot

# %% [markdown]
# 카테고리 별로 subplot을 생성하고 통계값(평균, 중앙값, 최대,최소,...) 을 계산해서 모든 subplot에 같은 종류의 그래프들을 시각화하는 방법.

# %%
# 요일(x축)별 tip(y축)의 평균을 막대 그래프(그래프 종류)로 시각화.
# 흡연 여부(subplot의 row)별, 시간(subplot의 column)별로 각각 Subplot들을 생성.
sns.catplot(x='day', y='tip', data=tips,
            kind='bar',         # kind=그래프 종류(bar, box, strip, count, ...)
            estimator=np.mean,  # estimator=통계 계산 함수. 기본값은 np.mean.
            row='smoker',       # row=subplot의 행을 나눌 기준이 되는 카테고리 변수(컬럼)
            col='time')         # col=subplot의 열을 나눌 기준이 되는 카테고리 변수(컬럼)
plt.show()

# %%
tips[(tips.smoker == 'Yes') & (tips.day == 'Thur') & (tips.time == 'Lunch')]['tip'].mean()
# Out:
# 3.0299999999999994

# %%
tips[(tips.smoker == 'Yes') & (tips.day == 'Fri')& (tips.time == 'Lunch')]['tip'].mean()
# Out:
# 2.28

# %%
sns.catplot(x='day', y='tip', data=tips,
            kind='box', row='smoker', col='time', hue='sex')

plt.show()

# %% [markdown]
# # Exercise-iris 데이터 셋

# %% [markdown]
# * seaborn 패키지의 예제 데이터 셋 'iris'를 DataFrame으로 생성.
# * 데이터 프레임을 탐색 - 출력, 요약 정보, 기술 통계량, 카테고리 타입 변수의 빈도수
# * 품종별로 subplot을 생성해서, 모든 숫자 타입 변수의 box plot을 시각화.
# * petal_width ~ petal_length 산점도. 품종별로 색깔을 다르게 시각화.
# * 모든 연속형 변수들 간의 상관 관계를 시각화 - Pair plot

# %%
iris = sns.load_dataset('iris')
iris.head() # iris.iloc[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
seto = iris[iris['species']=='setosa']
vers = iris[iris['species']=='versicolor']
virg = iris[iris['species']=='virginica']

# %% [markdown]
# ## Category plot

# %%
sns.catplot(col='species', data=iris, kind='box')
plt.show()

# %% [markdown]
# ## scatter plot

# %%
sns.scatterplot(x='petal_width', y='petal_length', data=iris,
                hue='species')

plt.show()

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(data=iris, hue='species')
plt.show()

# %% [markdown]
# # Exercise: mpg 데이터 셋

# %% [markdown]
# MPG(Mile Per Gallon): 자동차 연비
#
# * seaborn 패키지의 예제 데이터 셋 'mpg'를 로드해서 DataFrame 생성
# * DataFrame 탐색 - 출력, 요약 정보, 숫자 타입 기술 통계량, 카테고리 타입 빈도수
# * 산점도
#  * mpg(연비) ~ displacement(배기량)
#  * 2x2 모양의 subplot을 생성
#     * mpg ~ cylinders(실린더 개수)
#     * mpg ~ horsepower(마력)
#     * mpg ~ weight(무게)
#     * mpg ~ acceleration(가속도)
# * 빈도수 막대 그래프
#  * cyliners 빈도수
#  * origin(자동차 생산 지역) 빈도수
#  * model_year(자동차 생산 연도) 빈도수
#     * 선 그래프 가능?
#  * origin 별, cylinders 별 빈도수
# * 통계량 막대 그래프 - 2개의 subplot 생성
#
#     * cylinders 별 mpg의 중앙값(median)
#     * origin 별 mpg의 중앙값
# * Box plot
#  * 3개의 subplot을 생성
#     * mpg, displacement, weight box plot
#  * origin 별 mpg box plot
# * Histogram
#  * 4개의 subplot을 생성
#     * mpg, displacement, weight, model_year histogram
# * Pair plot

# %% [markdown]
# ## 데이터셋 준비

# %%
mpg = sns.load_dataset('mpg')

# %% [markdown]
# ## 데이터 탐색

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
mpg.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
mpg.origin.value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
mpg.name.value_counts()

# %%
mpg.model_year.value_counts().sort_index()
# pd.Series.sort_index(), # pd.DataFrame.sort_index() 
# index를 기준으로 오름차순 정렬
# Out:
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: model_year, dtype: int64

# %%
mpg.cylinders.value_counts()

# %% [markdown]
# ## Scatter plot

# %%
# mpg~displacement
sns.scatterplot(x='displacement', y='mpg', data=mpg ,hue='origin')
plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize=(8,8))

sns.scatterplot(x='mpg', y='cylinders', data=mpg,ax=ax[0,0])
sns.scatterplot(x='mpg', y='horsepower', data=mpg,ax=ax[0,1])
sns.scatterplot(x='mpg', y='weight', data=mpg,ax=ax[1,0])
sns.scatterplot(x='mpg', y='acceleration', data=mpg,ax=ax[1,1])
plt.show()

# %%
mpg.columns[[1,3,4,5]] #fancy indexing - ndarray, DataFrame, Series
# Out:
# Index(['cylinders', 'horsepower', 'weight', 'acceleration'], dtype='object')

# %%
columns = mpg.columns[[1,3,4,5]]
for i, col in enumerate(columns):
    print(col,i)
    r_idx = i //2
    c_idx = i % 2
    print(col, r_idx, c_idx)
# Out:
# cylinders 0
# cylinders 0 0
# horsepower 1
# horsepower 0 1
# weight 2
# weight 1 0
# acceleration 3
# acceleration 1 1

# %%
# scatter plot에서 x축으로 사용할 변수(컬럼)들 : [cyl, hp,wt,ac]
mpg.columns[[1,3,4,5]]

# Figure, subplot들을 생성
fig, ax = plt.subplots(2,2, figsize=(8,8))

# 각각의 subplot에 scatter plot을 그림.
for i , col in enumerate(columns):
    r_idx, c_idx = i //2 , i%2
    sns.scatterplot(x=col, y='mpg', data=mpg, ax=ax[r_idx, c_idx])
plt.show()

# %% [markdown]
# ## Count plot

# %%
sns.countplot(x='cylinders', data=mpg)
plt.show()

# %%
sns.countplot(x='origin', data=mpg)
plt.show()

# %%
sns.countplot(x='model_year', data=mpg)
plt.show()

# %%
sns.lineplot(x='model_year', data=mpg, estimator=np.size, marker='o', color='r' )
plt.grid()
plt.show()

# %%
index = mpg.model_year.value_counts().index
values = mpg.model_year.value_counts().values

sns.lineplot(x=index, y=values, data=df, marker='o', color='r' )
plt.xlabel('model_year') #이부분이 위 코드와 다름
plt.grid()
plt.show()

# %%
sns.countplot(x='origin', hue='cylinders', data=mpg)
plt.show()

# %% [markdown]
# ## 통계량 막대 그래프(Bar plot)

# %%
fig, ax = plt.subplots(1,2, figsize=(8,4))

sns.barplot(x='cylinders',y='mpg', 
            data=mpg, estimator=np.median, ax=ax[0])
sns.barplot(x='origin',y='mpg', 
            data=mpg, estimator=np.median, ax=ax[1])
plt.show()

# %% [markdown]
# ## Box plot

# %%
fig,ax = plt.subplots(1,3, figsize=(12,4))

# sns.boxplot(y='mpg', data=mpg, ax= ax[0])
# sns.boxplot(y='displacement', data=mpg, ax= ax[1])
# sns.boxplot(y='weight', data=mpg, ax= ax[2])

columns = (mpg.columns[[0,2,4]]) # [mpg,dis,wt]
for i, col in enumerate(columns):
    sns.boxplot(y=col, data=mpg, ax=ax[i])


plt.subplots_adjust(wspace=0.3)
plt.show()

# %%
sns.boxplot(x='origin', y='mpg', data=mpg)
plt.show()

# %% [markdown]
# ## Histogram

# %%
fig, ax = plt.subplots(2,2, figsize=(8,8))

sns.histplot(x='mpg', data=mpg, ax= ax[0,0], color='r')
sns.histplot(x='displacement', data=mpg, ax= ax[0,1],color='b')
sns.histplot(x='weight', data=mpg, ax= ax[1,0], color='y')
sns.histplot(x='model_year', data=mpg, ax= ax[1,1], color='g')
plt.show()

# %% [markdown]
# ## Pair plot

# %%
sns.pairplot(data=mpg, hue='origin', vars = ['mpg', 'displacement','weight', 'horsepower'])
# vars = 변수이름목록
plt.show()
