# %% [markdown]
# # 필요한 라이브러리 import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px 
import numpy as np

# %% [markdown]
# # 데이터 셋 준비

# %%
gapminder = px.data.gapminder()

# %% [markdown]
# gapminder DataFrame
#
# * 1952~ 2007년 5년 단위로 조사한 통계값.
# * 컬럼(변수)
#  * country: 국가 이름
#  * continent: 대륙 이름
#  * year: 연도
#  * lifeExp: 기대 수명
#  * pop: 인구 수
#  * gdppercap:1인당 GDP

# %% [markdown]
# # 데이터 탐색

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
gapminder.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716

# %%
gapminder.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %% [markdown]
# # Exercise:
#
# * 숫자 타입 변수들의 기술 통계량
# * 카테고리 타입 변수들의 빈도수
# * 국가 이름 개수
# * 대륙 이름 개수
# * 연도 개수
# * DataFrame에서 국가, 연도, 1인당 GDP 컬럼을 선택
# * DataFrame에서 1인당 GDP의 최댓값
# * DataFrame에서 1인당 GDP의 최댓값인 행(들)을 출력
# * DataFrame에서 1인당 GDP의 최솟값
# * DataFrame에서 1인당 GDP의 최솟값인 행(들)을 출력
# * DataFrame에서 1인당 GDP의 최댓값 또는 최솟값인 행들을 출력
# * DataFrame에서 기대수명의 최솟값, 최댓값 출력
# * DataFrame에서 기대수명의 최솟값 또는 최댓값인 행들을 출력
# * 연도별 기대 수명의 평균을 출력, 시각화
# * 연도별 1인당 GDP의 평균을 출력, 시각화
# * 연도별 전세계 인구수를 출력, 시각화
# * 연도별 대륙별 인구수를 출력, 시각화

# %% [markdown]
# ##기술통계량

# %%
gapminder.describe()
# Out:
#              year      lifeExp           pop      gdpPercap      iso_num
# count  1704.00000  1704.000000  1.704000e+03    1704.000000  1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081   425.880282
# std      17.26533    12.917107  1.061579e+08    9857.454543   248.305709
# min    1952.00000    23.599000  6.001100e+04     241.165876     4.000000
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309   208.000000
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989   410.000000
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346   638.000000
# max    2007.00000    82.603000  1.318683e+09  113523.132900   894.000000

# %%
gapminder[['lifeExp', 'pop', 'gdpPercap']].describe()
# Out:
#            lifeExp           pop      gdpPercap
# count  1704.000000  1.704000e+03    1704.000000
# mean     59.474439  2.960121e+07    7215.327081
# std      12.917107  1.061579e+08    9857.454543
# min      23.599000  6.001100e+04     241.165876
# 25%      48.198000  2.793664e+06    1202.060309
# 50%      60.712500  7.023596e+06    3531.846989
# 75%      70.845500  1.958522e+07    9325.462346
# max      82.603000  1.318683e+09  113523.132900

# %% [markdown]
# ## 카테고리 타입 빈도수

# %%
gapminder.country.value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %%
gapminder.continent.value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
gapminder.lifeExp.value_counts()
# Out:
# 69.390    4
# 66.800    3
# 78.770    3
# 70.750    3
# 76.420    3
#          ..
# 55.861    1
# 52.644    1
# 49.265    1
# 45.580    1
# 43.487    1
# Name: lifeExp, Length: 1626, dtype: int64

# %%
len(gapminder.country.unique())
# Out:
# 142

# %%
gapminder.country.value_counts()
# Out:
# Afghanistan          12
# Pakistan             12
# New Zealand          12
# Nicaragua            12
# Niger                12
#                      ..
# Eritrea              12
# Equatorial Guinea    12
# El Salvador          12
# Egypt                12
# Zimbabwe             12
# Name: country, Length: 142, dtype: int64

# %% [markdown]
# ## 중복되지 않는 값 찾기

# %%
len(gapminder.country.unique())
# Out:
# 142

# %%
len(gapminder.continent.unique())
# Out:
# 5

# %%
len(gapminder.year.unique())
# Out:
# 12

# %% [markdown]
# ## 컬럼선택

# %%
gapminder['country'] #Series
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
gapminder[['country']] #DataFrame
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
gapminder.columns[[0,2,5]]
# Out:
# Index(['country', 'year', 'gdpPercap'], dtype='object')

# %% [markdown]
# ## 조건에 맞는 값 찾기

# %%
print(f'gdpPercap.max:{gapminder.gdpPercap.max()}')
# Out:
# gdpPercap.max:113523.1329

# %%
gapminder[gapminder.gdpPercap == gapminder.gdpPercap.max()]
# Out:
#     country continent  year  lifeExp     pop    gdpPercap iso_alpha  iso_num
# 853  Kuwait      Asia  1957   58.033  212846  113523.1329       KWT      414

# %%
print(f'gdpPercap.min:{gapminder.gdpPercap.min()}')
# Out:
# gdpPercap.min:241.1658765

# %%
gapminder[gapminder.gdpPercap == gapminder.gdpPercap.min()]
# Out:
#               country continent  year  lifeExp       pop   gdpPercap  \
# 334  Congo, Dem. Rep.    Africa  2002   44.966  55379852  241.165876
#
#     iso_alpha  iso_num
# 334       COD      180

# %%
gapminder[(gapminder.gdpPercap == gapminder.gdpPercap.min()) | 
          (gapminder.gdpPercap == gapminder.gdpPercap.max())]
# Out:
#               country continent  year  lifeExp       pop      gdpPercap  \
# 334  Congo, Dem. Rep.    Africa  2002   44.966  55379852     241.165876
# 853            Kuwait      Asia  1957   58.033    212846  113523.132900
#
#     iso_alpha  iso_num
# 334       COD      180
# 853       KWT      414

# %%
#isin 함수 (a와 b 안에 들어있나요?)
gdp_max = gapminder.gdpPercap.max()
gdp_min = gapminder.gdpPercap.min()
gapminder[gapminder.gdpPercap.isin([gdp_max,gdp_min])]
# Out:
#               country continent  year  lifeExp       pop      gdpPercap  \
# 334  Congo, Dem. Rep.    Africa  2002   44.966  55379852     241.165876
# 853            Kuwait      Asia  1957   58.033    212846  113523.132900
#
#     iso_alpha  iso_num
# 334       COD      180
# 853       KWT      414

# %%
# 2007년에서 1인당 gdp가 최대인 국가, 최소인 국가
gdp_max = gapminder[gapminder['year']==2007]['gdpPercap'].max()
gdp_min = gapminder[gapminder['year']==2007]['gdpPercap'].min()
gapminder[gapminder.gdpPercap.isin([gdp_max,gdp_min])]
# Out:
#                country continent  year  lifeExp       pop     gdpPercap  \
# 335   Congo, Dem. Rep.    Africa  2007   46.462  64606759    277.551859
# 1151            Norway    Europe  2007   80.196   4627926  49357.190170
#
#      iso_alpha  iso_num
# 335        COD      180
# 1151       NOR      578

# %%
#기대수명 최솟값, 최댓값
print(f'lifeExp_Min:{gapminder.lifeExp.min()}')
print(f'lifeExp_Max:{gapminder.lifeExp.max()}')
# Out:
# lifeExp_Min:23.599
# lifeExp_Max:82.603

# %%
gapminder[(gapminder.lifeExp == gapminder.lifeExp.min()) | 
          (gapminder.lifeExp == gapminder.lifeExp.max())]
# Out:
#      country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 803    Japan      Asia  2007   82.603  127467972  31656.068060       JPN
# 1292  Rwanda    Africa  1992   23.599    7290203    737.068595       RWA
#
#       iso_num
# 803       392
# 1292      646

# %%
life_min = gapminder['lifeExp'].min()
life_max = gapminder['lifeExp'].max()

# %%
gapminder[gapminder.lifeExp.isin([life_min,life_max])]
# Out:
#      country continent  year  lifeExp        pop     gdpPercap iso_alpha  \
# 803    Japan      Asia  2007   82.603  127467972  31656.068060       JPN
# 1292  Rwanda    Africa  1992   23.599    7290203    737.068595       RWA
#
#       iso_num
# 803       392
# 1292      646

# %%
# Rwanda 자료만 선택
Rwanda = gapminder[gapminder['country'] == 'Rwanda']
Rwanda

# %%
sns.lineplot(x='year', y='lifeExp', data=Rwanda, marker='o')
plt.grid()
plt.show()

# %%
# Japan 데이터 선택
japan = gapminder[gapminder['country']=='Japan']
sns.lineplot(data=japan, x = 'year', y='lifeExp',
             marker='o')

plt.grid()
plt.show()

# %% [markdown]
# ## 그룹별 통계

# %% [markdown]
# 연도(year)별 기대 수명(lifeExp) 평균

# %%
years = gapminder.year.unique()
years
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007])

# %%
lifeExp_by_year = []  # 연도별 기대 수명 평균값을 저장할 리스트
for y in years:  # 각 연도별로 반복하면서
    subset = gapminder[gapminder.year == y]  # 연도별 부분집합 - 분리(split)
    avg = subset.lifeExp.mean()  # 부분집합에서 기대 수명 컬럼의 평균 계산 - 적용(apply)
    lifeExp_by_year.append(avg)  # 계산된 결과를 리스트에 추가 - 결합(combine)

lifeExp_by_year

# %%
lifeExp_by_year = pd.Series(data=lifeExp_by_year, index=years)
lifeExp_by_year

# %%
gapminder.groupby('year')['lifeExp'].mean()

# %% [markdown]
# `seaborn` 패키지의 함수들은 그룹별 통계 계산을 수행하는 기능을 가지고 있음

# %%
sns.barplot(x='year', y='lifeExp', estimator=np.mean, data=gapminder,
             ci=None)
plt.show()

# %% [markdown]
# 연도(year)별 1인당 GDP (gdpPercap) 평균

# %%
gdp = gapminder.gdpPercap.unique()
gdp
# Out:
# array([779.4453145, 820.8530296, 853.10071  , ..., 792.4499603,
#        672.0386227, 469.7092981])

# %%
gdpPercap_by_year = []  # 연도별 기대 수명 평균값을 저장할 리스트
for y in years:  # 각 연도별로 반복하면서
    subset = gapminder[gapminder.year == y]  # 연도별 부분집합 - 분리(split)
    avg = subset.gdpPercap.mean()  # 부분집합에서 기대 수명 컬럼의 평균 계산 - 적용(apply)
    gdpPercap_by_year.append(avg)  # 계산된 결과를 리스트에 추가 - 결합(combine)

gdpPercap_by_year
# Out:
# [3725.276045801409,
#  4299.4083448760575,
#  4725.812341961976,
#  5483.653046835208,
#  6770.082815282392,
#  7313.166420794365,
#  7518.901672698595,
#  7900.920217940843,
#  8158.608520688735,
#  9090.175363102113,
#  9917.848364685913,
#  11680.071819878172]

# %%
gdpPercap_by_year = pd.Series(data=gdpPercap_by_year, index=years)
gdpPercap_by_year
# Out:
# 1952     3725.276046
# 1957     4299.408345
# 1962     4725.812342
# 1967     5483.653047
# 1972     6770.082815
# 1977     7313.166421
# 1982     7518.901673
# 1987     7900.920218
# 1992     8158.608521
# 1997     9090.175363
# 2002     9917.848365
# 2007    11680.071820
# dtype: float64

# %%
gapminder.groupby('year')['gdpPercap'].mean()
# Out:
# year
# 1952     3725.276046
# 1957     4299.408345
# 1962     4725.812342
# 1967     5483.653047
# 1972     6770.082815
# 1977     7313.166421
# 1982     7518.901673
# 1987     7900.920218
# 1992     8158.608521
# 1997     9090.175363
# 2002     9917.848365
# 2007    11680.071820
# Name: gdpPercap, dtype: float64

# %%
sns.lineplot(x=gdpPercap_by_year.index , y=gdpPercap_by_year.values,
             color='r', marker='o',linestyle='--')

plt.grid()
plt.show()

# %%
sns.lineplot(x='year', y='gdpPercap', estimator=np.mean, data=gapminder, ci=None,
             marker='o', linestyle='--', color='r')

plt.grid()
plt.show()

# %% [markdown]
# 연도별 전세계 인구

# %%
gapminder.groupby('year')['pop'].sum()
# Out:
# year
# 1952    2406957150
# 1957    2664404580
# 1962    2899782974
# 1967    3217478384
# 1972    3576977158
# 1977    3930045807
# 1982    4289436840
# 1987    4691477418
# 1992    5110710260
# 1997    5515204472
# 2002    5886977579
# 2007    6251013179
# Name: pop, dtype: int64

# %%
pop_by_year = []
for y in years:
    subset = gapminder[gapminder.year == y]
    total = subset['pop'].sum()
    pop_by_year.append(total)

pop_by_year
# Out:
# [2406957150,
#  2664404580,
#  2899782974,
#  3217478384,
#  3576977158,
#  3930045807,
#  4289436840,
#  4691477418,
#  5110710260,
#  5515204472,
#  5886977579,
#  6251013179]

# %%
pop_by_year = pd.Series(data=pop_by_year, index=years)
pop_by_year
# Out:
# 1952    2406957150
# 1957    2664404580
# 1962    2899782974
# 1967    3217478384
# 1972    3576977158
# 1977    3930045807
# 1982    4289436840
# 1987    4691477418
# 1992    5110710260
# 1997    5515204472
# 2002    5886977579
# 2007    6251013179
# dtype: int64

# %%
sns.lineplot(x=pop_by_year.index, y=pop_by_year.values, marker='o')
plt.show()

# %%
sns.lineplot(x='year', y='pop', data=gapminder, marker='o',
             estimator=np.sum, ci=None)
plt.show()

# %% [markdown]
# ##2개 이상으로 컬럼으로 gruop by

# %%
# 연도별 대륙별 인구
pop_by_year_conti = gapminder.groupby(by=['year', 'continent'])['pop'].sum()
pop_by_year_conti
# Out:
# year  continent
# 1952  Africa        237640501
#       Americas      345152446
#       Asia         1395357351
#       Europe        418120846
#       Oceania        10686006
# 1957  Africa        264837738
#       Americas      386953916
#       Asia         1562780599
#       Europe        437890351
#       Oceania        11941976
# 1962  Africa        296516865
#       Americas      433270254
#       Asia         1696357182
#       Europe        460355155
#       Oceania        13283518
# 1967  Africa        335289489
#       Americas      480746623
#       Asia         1905662900
#       Europe        481178958
#       Oceania        14600414
# 1972  Africa        379879541
#       Americas      529384210
#       Asia         2150972248
#       Europe        500635059
#       Oceania        16106100
# 1977  Africa        433061021
#       Americas      578067699
#       Asia         2384513556
#       Europe        517164531
#       Oceania        17239000
# 1982  Africa        499348587
#       Americas      630290920
#       Asia         2610135582
#       Europe        531266901
#       Oceania        18394850
# 1987  Africa        574834110
#       Americas      682753971
#       Asia         2871220762
#       Europe        543094160
#       Oceania        19574415
# 1992  Africa        659081517
#       Americas      739274104
#       Asia         3133292191
#       Europe        558142797
#       Oceania        20919651
# 1997  Africa        743832984
#       Americas      796900410
#       Asia         3383285500
#       Europe        568944148
#       Oceania        22241430
# 2002  Africa        833723916
#       Americas      849772762
#       Asia         3601802203
#       Europe        578223869
#       Oceania        23454829
# 2007  Africa        929539692
#       Americas      898871184
#       Asia         3811953827
#       Europe        586098529
#       Oceania        24549947
# Name: pop, dtype: int64

# %%
pop_by_year_conti.index  #> MultiIndex: 2단계 이상의 인덱스. multi-level index
# Out:
# MultiIndex([(1952,   'Africa'),
#             (1952, 'Americas'),
#             (1952,     'Asia'),
#             (1952,   'Europe'),
#             (1952,  'Oceania'),
#             (1957,   'Africa'),
#             (1957, 'Americas'),
#             (1957,     'Asia'),
#             (1957,   'Europe'),
#             (1957,  'Oceania'),
#             (1962,   'Africa'),
#             (1962, 'Americas'),
#             (1962,     'Asia'),
#             (1962,   'Europe'),
#             (1962,  'Oceania'),
#             (1967,   'Africa'),
#             (1967, 'Americas'),
#             (1967,     'Asia'),
#             (1967,   'Europe'),
#             (1967,  'Oceania'),
#             (1972,   'Africa'),
#             (1972, 'Americas'),
#             (1972,     'Asia'),
#             (1972,   'Europe'),
#             (1972,  'Oceania'),
#             (1977,   'Africa'),
#             (1977, 'Americas'),
#             (1977,     'Asia'),
#             (1977,   'Europe'),
#             (1977,  'Oceania'),
#             (1982,   'Africa'),
#             (1982, 'Americas'),
#             (1982,     'Asia'),
#             (1982,   'Europe'),
#             (1982,  'Oceania'),
#             (1987,   'Africa'),
#             (1987, 'Americas'),
#             (1987,     'Asia'),
#             (1987,   'Europe'),
#             (1987,  'Oceania'),
#             (1992,   'Africa'),
#             (1992, 'Americas'),
#             (1992,     'Asia'),
#             (1992,   'Europe'),
#             (1992,  'Oceania'),
#             (1997,   'Africa'),
#             (1997, 'Americas'),
#             (1997,     'Asia'),
#             (1997,   'Europe'),
#             (1997,  'Oceania'),
#             (2002,   'Africa'),
#             (2002, 'Americas'),
#             (2002,     'Asia'),
#             (2002,   'Europe'),
#             (2002,  'Oceania'),
#             (2007,   'Africa'),
#             (2007, 'Americas'),
#             (2007,     'Asia'),
#             (2007,   'Europe'),
#             (2007,  'Oceania')],
#            names=['year', 'continent'])

# %%
pop_by_year_conti.values
# Out:
# array([ 237640501,  345152446, 1395357351,  418120846,   10686006,
#         264837738,  386953916, 1562780599,  437890351,   11941976,
#         296516865,  433270254, 1696357182,  460355155,   13283518,
#         335289489,  480746623, 1905662900,  481178958,   14600414,
#         379879541,  529384210, 2150972248,  500635059,   16106100,
#         433061021,  578067699, 2384513556,  517164531,   17239000,
#         499348587,  630290920, 2610135582,  531266901,   18394850,
#         574834110,  682753971, 2871220762,  543094160,   19574415,
#         659081517,  739274104, 3133292191,  558142797,   20919651,
#         743832984,  796900410, 3383285500,  568944148,   22241430,
#         833723916,  849772762, 3601802203,  578223869,   23454829,
#         929539692,  898871184, 3811953827,  586098529,   24549947])

# %%
# MultiIndex를 사용한 인덱싱
pop_by_year_conti.loc[(2007, 'Oceania')]

# %%
pop_by_year_conti.loc[(2007, 'Europe')]

# %%
gapminder.groupby(by=['continent', 'year'])['pop'].sum()

# %% [markdown]
# 연도별 대륙별 인구 시각화

# %%
sns.lineplot(x='year', y='pop', data=gapminder, hue='continent', 
            marker='o', estimator=np.sum, ci=None)
plt.grid()
plt.show()

# %%
sns.relplot(x='year', y='pop', col='continent', 
            data=gapminder, hue='continent', kind='line',
            estimator=np.sum, ci=None)
plt.show()

# %%
sns.catplot(x='year', y='pop', col='continent', 
            data=gapminder, hue='continent', kind='bar',
            estimator=np.sum, ci=None)
plt.show()
