# %% [markdown]
# #Colab Notebook #목차를 만드는 기능

# %%
print('안녕하세요!')
# Out:
# 안녕하세요!

# %% [markdown]
# # python 버전 확인

# %%
import sys #sys 모듈을 사용하겠다.

print(sys.version)
# Out:
# 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0]

# %% [markdown]
# # 여러가지 print 방법

# %%
print('Hello Python!')
# 파이썬에서 문자열은 작은 따옴표 ('') 또는 큰 따옴표 ("")를 사용.
# Out:
# Hello Python!

# %% [markdown]
# `print()` 함수에 argument(인수)를 여러 개를 전달하면, 각각의 argument들을 공백으로 연결해서 한 줄에 출력.

# %%
print('Hello','안녕','Bon Jour')
# Out:
# Hello 안녕 Bon Jour

# %%
print('Hello','안녕','Bon Jour', sep=';;')
# print 함수의 sep argument의 값을 바꿔주면, 출력 시 구분자(sep)를 설정할 수 있다.
# Out:
# Hello;;안녕;;Bon Jour

# %%
print(1, '+', 2, '=', 3)
# Out:
# 1 + 2 = 3

# %%
print(1, '+', 2, '=', 1+2)
# Out:
# 1 + 2 = 3

# %% [markdown]
# placeholder 문자열과 `format()` 메서드(함수)를 사용해서 출력하는 방법 :

# %%
print('{}+{}={}'.format(1,2,(1+2)))
# Out:
# 1+2=3

# %%
# 변수 (variable): 값을 저장하는 메모리 공간.
x = 100 # 변수 x에 숫자 10을 저장.
y = 20

# %%
print('{} + {}= {}'.format(x,y,(x+y)))
# Out:
# 100 + 20= 120

# %%
print(f'{x} + {y} = {x+y}')
# Out:
# 100 + 20 = 120

# %%
name = '오쌤'
print (f'안녕하세요, {name}')
# Out:
# 안녕하세요, 오쌤

# %% [markdown]
# 키보드로 문자열을 입력받아서, 화면에 입력받은 내용을 출력.

# %%
name = input ('이름을 입력하세요>>>')
print (f'안녕하세요, {name} 님!')
# Out:
# 이름을 입력하세요>>>정민희
# 안녕하세요, 정민희 님!
